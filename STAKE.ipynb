# %%
import pandas as pd
import numpy as np

# %%
original_data = pd.read_csv('C:\\Users\\Admin\\Desktop\\600000SH.csv',encoding='gbk')
original_data.head()
# Out:
#           代码    简称          日期  前收盘价(元)  开盘价(元)  最高价(元)  最低价(元)  收盘价(元)  \
# 0  600000.SH  浦发银行  1999-11-10      NaN  3.6043  3.6409  3.2988  3.3904
# 1  600000.SH  浦发银行  1999-11-11   3.3904  3.3697  3.4674  3.3636  3.3856
# 2  600000.SH  浦发银行  1999-11-12   3.3856  3.4039  3.4576  3.3929  3.4271
# 3  600000.SH  浦发银行  1999-11-15   3.4271  3.4454  3.4515  3.3843  3.3904
# 4  600000.SH  浦发银行  1999-11-16   3.3904  3.4063  3.4173  3.2353  3.2438
#
#         成交量(股)       成交金额(元)  ...  B股流通市值(元)        总市值(元)  A股流通股本(股)  \
# 0  174085100.0  4.859102e+09  ...        NaN  6.687750e+10  320000000
# 1   29403500.0  8.215822e+08  ...        NaN  6.678110e+10  320000000
# 2   15008000.0  4.215916e+08  ...        NaN  6.760050e+10  320000000
# 3   11921100.0  3.329528e+08  ...        NaN  6.687750e+10  320000000
# 4   23223100.0  6.289083e+08  ...        NaN  6.398550e+10  320000000
#
#    B股流通股本(股)      总股本(股)      市盈率      市净率      市销率      市现率  Unnamed: 24
# ...

# %% [markdown]
# ##评估数据

# %%
original_data.sample(10)
# Out:
#              代码    简称          日期  前收盘价(元)   开盘价(元)   最高价(元)   最低价(元)  \
# 1231  600000.SH  浦发银行  2004-12-27   1.3532   1.3513   1.3608   1.3304
# 48    600000.SH  浦发银行  2000-01-20   2.9482   2.9469   3.0117   2.9445
# 917   600000.SH  浦发银行  2003-09-10   1.8772   1.8753   1.8998   1.8565
# 1654  600000.SH  浦发银行  2006-09-25   2.7134   2.7006   2.7210   2.5986
# 3891  600000.SH  浦发银行  2015-12-10  19.2300  19.3400  19.8800  19.1100
# 1142  600000.SH  浦发银行  2004-08-17   1.6558   1.6539   1.6654   1.6349
# 1032  600000.SH  浦发银行  2004-03-09   1.9524   1.9524   1.9750   1.9355
# 304   600000.SH  浦发银行  2001-02-26   2.4299   2.5394   2.5394   2.4447
# 3077  600000.SH  浦发银行  2012-08-02   6.4523   6.4776   6.5535   6.4523
# 843   600000.SH  浦发银行  2003-05-29   2.5108   2.4996   2.5220   2.4530
#
#        收盘价(元)      成交量(股)       成交金额(元)  ...  B股流通市值(元)        总市值(元)  \
# 1231   1.3380   2807350.0  1.980505e+07  ...        NaN  2.752245e+10
# ...

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4013 entries, 0 to 4012
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   代码           4013 non-null   object
#  1   简称           4013 non-null   object
#  2   日期           4013 non-null   object
#  3   前收盘价(元)      4012 non-null   float64
#  4   开盘价(元)       4013 non-null   float64
#  5   最高价(元)       4013 non-null   float64
#  6   最低价(元)       4013 non-null   float64
#  7   收盘价(元)       4013 non-null   float64
#  8   成交量(股)       3895 non-null   float64
#  9   成交金额(元)      3895 non-null   float64
#  10  涨跌(元)        4012 non-null   float64
#  11  涨跌幅(%)       4012 non-null   float64
#  12  均价(元)        3895 non-null   float64
#  13  换手率(%)       3895 non-null   float64
#  14  A股流通市值(元)    4013 non-null   float64
#  15  B股流通市值(元)    0 non-null      float64
#  16  总市值(元)       4013 non-null   float64
#  17  A股流通股本(股)    4013 non-null   int64
# ...

# %%
original_data.drop("Unnamed: 24",axis=1,inplace=True)

# %%
original_data[original_data["成交量(股)"].isnull()]
# Out:
#              代码    简称          日期  前收盘价(元)   开盘价(元)   最高价(元)   最低价(元)  \
# 110   600000.SH  浦发银行  2000-05-08   3.0545   3.0545   3.0545   3.0545
# 247   600000.SH  浦发银行  2000-11-22   2.6919   2.6919   2.6919   2.6919
# 364   600000.SH  浦发银行  2001-05-28   2.4742   2.4742   2.4742   2.4742
# 436   600000.SH  浦发银行  2001-09-05   1.9331   1.9331   1.9331   1.9331
# 536   600000.SH  浦发银行  2002-02-04   1.7278   1.7278   1.7278   1.7278
# ...         ...   ...         ...      ...      ...      ...      ...
# 3946  600000.SH  浦发银行  2016-03-04  18.4500  18.4500  18.4500  18.4500
# 3947  600000.SH  浦发银行  2016-03-07  18.4500  18.4500  18.4500  18.4500
# 3948  600000.SH  浦发银行  2016-03-08  18.4500  18.4500  18.4500  18.4500
# 3949  600000.SH  浦发银行  2016-03-09  18.4500  18.4500  18.4500  18.4500
# 3950  600000.SH  浦发银行  2016-03-10  18.4500  18.4500  18.4500  18.4500
#
#        收盘价(元)  成交量(股)  成交金额(元)  ...     A股流通市值(元)  B股流通市值(元)        总市值(元)  \
# ...

# %%
original_data[(original_data["成交量(股)"].isnull()) & (original_data["成交金额(元)"].isnull())]
# Out:
#              代码    简称          日期  前收盘价(元)   开盘价(元)   最高价(元)   最低价(元)  \
# 110   600000.SH  浦发银行  2000-05-08   3.0545   3.0545   3.0545   3.0545
# 247   600000.SH  浦发银行  2000-11-22   2.6919   2.6919   2.6919   2.6919
# 364   600000.SH  浦发银行  2001-05-28   2.4742   2.4742   2.4742   2.4742
# 436   600000.SH  浦发银行  2001-09-05   1.9331   1.9331   1.9331   1.9331
# 536   600000.SH  浦发银行  2002-02-04   1.7278   1.7278   1.7278   1.7278
# ...         ...   ...         ...      ...      ...      ...      ...
# 3946  600000.SH  浦发银行  2016-03-04  18.4500  18.4500  18.4500  18.4500
# 3947  600000.SH  浦发银行  2016-03-07  18.4500  18.4500  18.4500  18.4500
# 3948  600000.SH  浦发银行  2016-03-08  18.4500  18.4500  18.4500  18.4500
# 3949  600000.SH  浦发银行  2016-03-09  18.4500  18.4500  18.4500  18.4500
# 3950  600000.SH  浦发银行  2016-03-10  18.4500  18.4500  18.4500  18.4500
#
#        收盘价(元)  成交量(股)  成交金额(元)  ...     A股流通市值(元)  B股流通市值(元)        总市值(元)  \
# ...

# %%
cleaned_data = original_data.copy()

# %%
cleaned_data
# Out:
#              代码    简称          日期  前收盘价(元)   开盘价(元)   最高价(元)   最低价(元)  \
# 0     600000.SH  浦发银行  1999-11-10      NaN   3.6043   3.6409   3.2988
# 1     600000.SH  浦发银行  1999-11-11   3.3904   3.3697   3.4674   3.3636
# 2     600000.SH  浦发银行  1999-11-12   3.3856   3.4039   3.4576   3.3929
# 3     600000.SH  浦发银行  1999-11-15   3.4271   3.4454   3.4515   3.3843
# 4     600000.SH  浦发银行  1999-11-16   3.3904   3.4063   3.4173   3.2353
# ...         ...   ...         ...      ...      ...      ...      ...
# 4008  600000.SH  浦发银行  2016-06-02  18.1900  18.2000  18.3000  17.9300
# 4009  600000.SH  浦发银行  2016-06-03  18.0200  18.1200  18.1300  17.9000
# 4010  600000.SH  浦发银行  2016-06-06  18.0100  18.0500  18.1100  17.9700
# 4011  600000.SH  浦发银行  2016-06-07  18.0200  18.1000  18.1300  17.9700
# 4012  600000.SH  浦发银行  2016-06-08  18.0200  18.0100  18.0700  17.9700
#
#        收盘价(元)       成交量(股)       成交金额(元)  ...     A股流通市值(元)  B股流通市值(元)  \
# ...

# %%
original_data["前收盘价(元)"].min()
# Out:
# 1.2546

# %%
original_data["日期"] = pd.to_datetime(original_data["日期"])

# %%
original_data["日期"]
# Out:
# 0      1999-11-10
# 1      1999-11-11
# 2      1999-11-12
# 3      1999-11-15
# 4      1999-11-16
#           ...
# 4008   2016-06-02
# 4009   2016-06-03
# 4010   2016-06-06
# 4011   2016-06-07
# 4012   2016-06-08
# Name: 日期, Length: 4013, dtype: datetime64[ns]
